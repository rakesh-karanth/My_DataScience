# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Relplot (relation plot)

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)

# %% [markdown]
# Relplot can find the relation between max of 5 features

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style= 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'day', style= 'time', size = 'sex')

# %%
iris = sns.load_dataset('iris')

# %%
sns.scatterplot(x=iris.sepal_length, y= iris.petal_length)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### Bar plot

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.barplot('class', 'age', data = titanic)
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ### Catplot (Categorical plot)

# %%
sns.catplot('day', 'total_bill',data = tips)
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('day', 'total_bill',data = tips, jitter = False)
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Below plot can be used to detect outlier

# %%
sns.catplot('day', 'total_bill',data = tips, kind= 'box')
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('day', 'total_bill',data = tips, kind= 'swarm')
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot('day', 'total_bill',data = tips, kind= 'violin')
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Box plot

# %%
sns.boxplot('day', 'total_bill',data = tips)
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Distribution plot

# %%
import numpy as np
x = np.random.randn(100)
x
# Out:
# array([-1.51433979, -0.02405598,  1.06284133,  1.95826228,  0.1577922 ,
#        -1.65278171, -0.76617774, -1.18644193,  0.36876426,  1.43749132,
#        -0.57379278,  0.44553533,  2.24817581, -0.16202656,  0.07923762,
#         0.01845431,  2.45208375,  0.21674833,  0.18934567, -0.63024943,
#         0.04725896, -1.10919813,  0.26881449, -1.57650169, -0.06597537,
#         1.4673161 ,  0.48926508, -1.52462218,  0.31329561, -0.10314931,
#        -1.49608149, -0.71609247, -0.92256307, -0.04726992, -0.32378429,
#         0.19781506,  0.64230619,  0.6451666 , -0.53167986,  0.14869128,
#        -0.21234148,  0.71706803,  0.88990159, -1.29946788, -1.01985427,
#         0.95798757, -0.13035091, -0.20484401, -0.25133987, -1.12037621,
#        -0.81607545, -0.92243727, -0.41469063,  0.07058823, -0.12369107,
#        -0.27715851,  1.2473903 , -1.25416645, -0.31061614,  1.11682397,
#         0.13974228,  0.39915776, -0.48893062, -0.34239883,  0.24719307,
# ...

# %%
sns.displot(x)

# %%
sns.displot(x, kde= True)

# %%
sns.displot(x, kind = 'kde')

# %% [markdown]
# ### Regplot - regression plot

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(tips)
